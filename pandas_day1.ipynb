# %%
import pandas as pd

# %%
df = pd.DataFrame([[2,4,6],[10,20,30]]) #pass a list within  list since we want it like a table  
#each list is a row of the table 
df
# Out:
#     0   1   2
# 0   2   4   6
# 1  10  20  30

# %% [markdown]
# 0,1 are the indexes for the rows
#
# 0,1,2 are column names for the table

# %%
df  = pd.DataFrame([[2,4,6],[10,20,30]],columns=["Price", "Age","Value"])
df
# Out:
#    Price  Age  Value
# 0      2    4      6
# 1     10   20     30

# %%
df = pd.DataFrame([[2,4,6],[10,20,30]],columns=["Price","Age","Value"], index = ["First","Second"])
df
# Out:
#         Price  Age  Value
# First       2    4      6
# Second     10   20     30

# %%
#Another way to create df 
#Using list of dictionaries
df2 = pd.DataFrame([{"Name":"John"},{"Name":"Jack"}])
df2
# Out:
#    Name
# 0  John
# 1  Jack

# %%
df2 = pd.DataFrame([{"Name":"John","Surname":"Harlow"},{"Name":"Jack"}])
df2
# Out:
#    Name Surname
# 0  John  Harlow
# 1  Jack     NaN

# %%
df
# Out:
#         Price  Age  Value
# First       2    4      6
# Second     10   20     30

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Finding out methods in pandas 
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
df.mean() #we get the mean of all the columns
# Out:
# Price     6.0
# Age      12.0
# Value    18.0
# dtype: float64

# %%
#Calculating the mean of the entire dataframe
#Caculates the mean of the above values 
df.mean().mean()
# Out:
# 12.0

# %%
type(df.mean())
# Out:
# pandas.core.series.Series

# %%
df.Price
# Out:
# First      2
# Second    10
# Name: Price, dtype: int64

# %%
df.Price.max()
# Out:
# 10

# %%
df.Price.mean()
# Out:
# 6.0

# %%
#Filehandling xlsx,csv,json,txt using pandas 
#short cut 
import os 
os.listdir() #returns a list of files and folder names in the current directory
# Out:
# ['pandas_day1.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
df1 = pd.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pd.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country
# 0   1     3666 21st St  San Francisco          CA 94114     USA  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pd.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv("supermarkets-semi-colons.txt",sep = ";")
df5
# Out:
#    ID          Address           City             State Country          Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pd.read_csv?

# %%
df7  = pd.read_json("https://pythonhow.com/media/data/supermarkets.json")
df7
# Out:
#            Address           City Country  Employees  ID         Name
# 0     3666 21st St  San Francisco     USA          8   1      Madeira  \
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %% [markdown]
# The first row in the output is the header which gives names to all columns

# %%
df8 =  pd.read_csv("data.txt",header=None)  #if data doesnt have a header write header = None
df8
# Out:
#                                          0
# 0        1   301    9 1.708 57.0    2    2
# 1        2   451    8 1.724 67.5    2    2
# 2        3   501    7 1.720 54.5    2    2
# 3        4   642    9 1.558 53.0    1    2
# 4        5   901    9 1.895 57.0    1    2
# ..                                     ...
# 649    650 73041   16 4.270 67.0    1    1
# 650    651 73042   15 3.727 68.0    1    1
# 651    652 73751   18 2.853 60.0    2    2
# 652    653 75852   16 2.795 63.0    2    1
# 653    654 77151   15 3.211 66.5    2    2
#
# [654 rows x 1 columns]

# %%
print(df8.columns)
print(len(df8.columns))
# Out:
# Index([0], dtype='int64')
# 1

# %%
df8.columns = ["Sno"]
df8
# Out:
#                                        Sno
# 0        1   301    9 1.708 57.0    2    2
# 1        2   451    8 1.724 67.5    2    2
# 2        3   501    7 1.720 54.5    2    2
# 3        4   642    9 1.558 53.0    1    2
# 4        5   901    9 1.895 57.0    1    2
# ..                                     ...
# 649    650 73041   16 4.270 67.0    1    1
# 650    651 73042   15 3.727 68.0    1    1
# 651    652 73751   18 2.853 60.0    2    2
# 652    653 75852   16 2.795 63.0    2    1
# 653    654 77151   15 3.211 66.5    2    2
#
# [654 rows x 1 columns]
